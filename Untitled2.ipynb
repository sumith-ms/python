# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.56789,87.9999,40,'hyderabad']
k
# Out:
# [4, 2.56789, 87.9999, 40, 'hyderabad']

# %%
pd.Series(k)
# Out:
# 0            4
# 1      2.56789
# 2      87.9999
# 3           40
# 4    hyderabad
# dtype: object

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([26, 40, 31, 20, 21, 46, 48, 45, 46, 33, 36, 37, 30, 39, 30])

# %%
pd.Series(a)
# Out:
# 0     26
# 1     40
# 2     31
# 3     20
# 4     21
# 5     46
# 6     48
# 7     45
# 8     46
# 9     33
# 10    36
# 11    37
# 12    30
# 13    39
# 14    30
# dtype: int64

# %%
s=pd.Series(a)
s
# Out:
# 0     26
# 1     40
# 2     31
# 3     20
# 4     21
# 5     46
# 6     48
# 7     45
# 8     46
# 9     33
# 10    36
# 11    37
# 12    30
# 13    39
# 14    30
# dtype: int64

# %%
s[4:10]
# Out:
# 4    21
# 5    46
# 6    48
# 7    45
# 8    46
# 9    33
# dtype: int64

# %%
np.random.seed(34) # To come same values
b=np.random.randint(100,200,(6,5))

# %%
b.ndim
# Out:
# 2

# %%
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','adds','country'],index=[3,6,8,6,9,0])
df
# Out:
#    Roll  name  age  adds  country
# 3   133   185  168   135      169
# 6   111   178  129   118      129
# 8   189   129  120   196      162
# 6   105   120  151   119      185
# 9   121   163  172   142      184
# 0   172   177  136   102      137

# %%
df.loc[3]
# Out:
# Roll       133
# name       185
# age        168
# adds       135
# country    169
# Name: 3, dtype: int64

# %%
df.iloc[0,2]
# Out:
# 168

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
df.age
# Out:
# 3    168
# 6    129
# 8    120
# 6    151
# 9    172
# 0    136
# Name: age, dtype: int64
